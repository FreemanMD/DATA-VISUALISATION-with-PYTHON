# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats as st
import seaborn as sns

# %% [markdown]
# import warnings
# warnings.filterwarnings("ignore")
# warnings.warn("this will not show")
#
# plt.rcParams["figure.figsize"] = (10, 6)
#
# sns.set_style("whitegrid")
# pd.set_option('display.float_format', lambda x: '%.3f' % x)
#
# # Set it None to display all rows in the dataframe
# # pd.set_option('display.max_rows', None)
#
# # Set it to None to display all columns in the dataframe
# pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
df0 = pd.read_csv("adult_eda.csv")
df = df0.copy()

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
# Your Code is Here
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Your Code is Here
df.shape
# Out:
# (32561, 15)

# %%
# Your Code is Here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# Check if the Dataset have any Duplicate

# Your Code is Here

df.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
# Drop Duplicates

# Your Code is Here

df.drop_duplicates(inplace=True)

# %%
# Check the shape of the Dataset

# Your Code is Here
df.shape
# Out:
# (32537, 15)

# %% [raw]
# Desired Output:
#
# (32537, 15)

# %%
# Your Code is Here

df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             32537.0      38.585549      13.637984     17.0      28.0
# fnlwgt          32537.0  189780.848511  105556.471009  12285.0  117827.0
# education-num   31735.0      10.084008       2.575060      1.0       9.0
# capital-gain    32537.0    1078.443741    7387.957424      0.0       0.0
# capital-loss    32537.0      87.368227     403.101833      0.0       0.0
# hours-per-week  32537.0      40.440329      12.346889      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  236993.0  1484705.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %% [markdown]
# **Rename the features of;**<br>
# **``"education-num"``**, **``"marital-status"``**, **``"capital-gain"``**, **``"capital-loss"``**, **``"hours-per-week"``**, **``"native-country"``** **as**<br>
# **``"education_num"``**, **``"marital_status"``**, **``"capital_gain"``**, **``"capital_loss"``**, **``"hours_per_week"``**, **``"native_country"``**, **respectively and permanently.**

# %%
# Your Code is Here

df.rename(columns = {"education-num":"education_num", "marital-status":"marital_status", 
                     "capital-gain":"capital_gain", "capital-loss":"capital_loss", 
                     "hours-per-week":"hours_per_week", "native-country": "native_country"}, inplace = True)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
# Check the sum of Missing Values per column

# Your Code is Here

df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# Check the Percentage of Missing Values

# Your Code is Here

df.isnull().mean()*100
# Out:
# age                0.000000
# workclass          0.000000
# fnlwgt             0.000000
# education          0.000000
# education_num      2.464886
# marital_status     0.000000
# occupation         0.000000
# relationship      15.563820
# race               0.000000
# sex                0.000000
# capital_gain       0.000000
# capital_loss       0.000000
# hours_per_week     0.000000
# native_country     0.000000
# salary             0.000000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
# Your Code is Here

df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# Your Code is Here

df[['workclass', 'education', 'marital_status', 'occupation', 'relationship', 
   'race', 'sex','native_country','salary']].agg(["count", "nunique"]).T
# Out:
#                 count  nunique
# workclass       32537        9
# education       32537       16
# marital_status  32537        7
# occupation      32537       15
# relationship    27473        5
# race            32537        5
# sex             32537        2
# native_country  32537       42
# salary          32537        2

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/WspBGfZ/US-Citicens3.png)

# %% [markdown]
# **Assign the Columns (Features) of object data type as** **``"object_col"``**

# %%
# Your Code is Here
object_col = df.columns
object_col
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].value_counts(dropna=False))
    print("--"*20)
# Out:
# age
# ----------------
# 36    898
# 31    888
# 34    886
# 23    876
# 33    875
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: age, Length: 73, dtype: int64
# ----------------------------------------
# workclass
# ----------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ----------------------------------------
# fnlwgt
# ----------------
# 164190    13
# 123011    13
# 203488    13
# 148995    12
# 113364    12
#           ..
# 138342     1
# 158040     1
# 232784     1
# 325573     1
# 257302     1
# Name: fnlwgt, Length: 21648, dtype: int64
# ----------------------------------------
# education
# ----------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ----------------------------------------
# education_num
# ----------------
# 9.0     10208
# 10.0     7089
# 13.0     5245
# 14.0     1686
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# NaN       802
# 4.0       630
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       329
# 2.0       159
# 1.0        49
# Name: education_num, dtype: int64
# ----------------------------------------
# marital_status
# ----------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64
# ----------------------------------------
# occupation
# ----------------
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64
# ----------------------------------------
# relationship
# ----------------
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64
# ----------------------------------------
# race
# ----------------
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64
# ----------------------------------------
# sex
# ----------------
# Male      21775
# Female    10762
# Name: sex, dtype: int64
# ----------------------------------------
# capital_gain
# ----------------
# 0        29825
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: capital_gain, Length: 119, dtype: int64
# ----------------------------------------
# capital_loss
# ----------------
# 0       31018
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: capital_loss, Length: 92, dtype: int64
# ----------------------------------------
# hours_per_week
# ----------------
# 40    15204
# 50     2817
# 45     1823
# 60     1475
# 35     1296
#       ...
# 82        1
# 92        1
# 87        1
# 74        1
# 94        1
# Name: hours_per_week, Length: 94, dtype: int64
# ----------------------------------------
# native_country
# ----------------
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64
# ----------------------------------------
# salary
# ----------------
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64
# ----------------------------------------

# %% [markdown]
# **Check if the Dataset has any Question Mark** **``"?"``**

# %%
# Your Code is Here

df.isin(['?']).any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %%
for col in object_col:
    print(col)
    print("--"*8)
    print(df[col].unique())
    print("--"*20)
# Out:
# age
# ----------------
# [39 50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
# ----------------------------------------
# workclass
# ----------------
# ['State-gov' 'Self-emp-not-inc' 'Private' 'Federal-gov' 'Local-gov' '?'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# ----------------------------------------
# fnlwgt
# ----------------
# [ 77516  83311 215646 ...  34066  84661 257302]
# ----------------------------------------
# education
# ----------------
# ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool' '12th']
# ----------------------------------------
# education_num
# ----------------
# [13.  9.  7. 14.  5. 10. 12. nan  4. 16. 11. 15.  3.  6.  2.  1.  8.]
# ----------------------------------------
# marital_status
# ----------------
# ['Never-married' 'Married-civ-spouse' 'Divorced' 'Married-spouse-absent'
#  'Separated' 'Married-AF-spouse' 'Widowed']
# ----------------------------------------
# occupation
# ----------------
# ['Adm-clerical' 'Exec-managerial' 'Handlers-cleaners' 'Prof-specialty'
#  'Other-service' 'Sales' 'Craft-repair' 'Transport-moving'
#  'Farming-fishing' 'Machine-op-inspct' 'Tech-support' '?'
#  'Protective-serv' 'Armed-Forces' 'Priv-house-serv']
# ----------------------------------------
# relationship
# ----------------
# ['Not-in-family' 'Husband' 'Wife' nan 'Unmarried' 'Other-relative']
# ----------------------------------------
# race
# ----------------
# ['White' 'Black' 'Asian-Pac-Islander' 'Amer-Indian-Eskimo' 'Other']
# ----------------------------------------
# sex
# ----------------
# ['Male' 'Female']
# ----------------------------------------
# capital_gain
# ----------------
# [ 2174     0 14084  5178  5013  2407 14344 15024  7688 34095  4064  4386
#   7298  1409  3674  1055  3464  2050  2176   594 20051  6849  4101  1111
#   8614  3411  2597 25236  4650  9386  2463  3103 10605  2964  3325  2580
#   3471  4865 99999  6514  1471  2329  2105  2885 25124 10520  2202  2961
#  27828  6767  2228  1506 13550  2635  5556  4787  3781  3137  3818  3942
#    914   401  2829  2977  4934  2062  2354  5455 15020  1424  3273 22040
#   4416  3908 10566   991  4931  1086  7430  6497   114  7896  2346  3418
#   3432  2907  1151  2414  2290 15831 41310  4508  2538  3456  6418  1848
#   3887  5721  9562  1455  2036  1831 11678  2936  2993  7443  6360  1797
#   1173  4687  6723  2009  6097  2653  1639 18481  7978  2387  5060]
# ----------------------------------------
# capital_loss
# ----------------
# [   0 2042 1408 1902 1573 1887 1719 1762 1564 2179 1816 1980 1977 1876
#  1340 2206 1741 1485 2339 2415 1380 1721 2051 2377 1669 2352 1672  653
#  2392 1504 2001 1590 1651 1628 1848 1740 2002 1579 2258 1602  419 2547
#  2174 2205 1726 2444 1138 2238  625  213 1539  880 1668 1092 1594 3004
#  2231 1844  810 2824 2559 2057 1974  974 2149 1825 1735 1258 2129 2603
#  2282  323 4356 2246 1617 1648 2489 3770 1755 3683 2267 2080 2457  155
#  3900 2201 1944 2467 2163 2754 2472 1411]
# ----------------------------------------
# hours_per_week
# ----------------
# [40 13 16 45 50 80 30 35 60 20 52 44 15 25 38 43 55 48 58 32 70  2 22 56
#  41 28 36 24 46 42 12 65  1 10 34 75 98 33 54  8  6 64 19 18 72  5  9 47
#  37 21 26 14  4 59  7 99 53 39 62 57 78 90 66 11 49 84  3 17 68 27 85 31
#  51 77 63 23 87 88 73 89 97 94 29 96 67 82 86 91 81 76 92 61 74 95]
# ----------------------------------------
# native_country
# ----------------
# ['United-States' 'Cuba' 'Jamaica' 'India' '?' 'Mexico' 'South'
#  'Puerto-Rico' 'Honduras' 'England' 'Canada' 'Germany' 'Iran'
#  'Philippines' 'Italy' 'Poland' 'Columbia' 'Cambodia' 'Thailand' 'Ecuador'
#  'Laos' 'Taiwan' 'Haiti' 'Portugal' 'Dominican-Republic' 'El-Salvador'
#  'France' 'Guatemala' 'China' 'Japan' 'Yugoslavia' 'Peru'
#  'Outlying-US(Guam-USVI-etc)' 'Scotland' 'Trinadad&Tobago' 'Greece'
#  'Nicaragua' 'Vietnam' 'Hong' 'Ireland' 'Hungary' 'Holand-Netherlands']
# ----------------------------------------
# salary
# ----------------
# ['<=50K' '>50K']
# ----------------------------------------

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## Salary (Target Feature)

# %% [markdown]
# **Check the count of person in each "salary" levels and visualize it with a countplot**

# %%
# Your Code is Here
v_sal = df.salary.value_counts()
v_sal
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax = sns.countplot(x="salary", data=df)
ax.bar_label(ax.containers[0], color="blue", size=15);

# %% [markdown]
# **Check the percentage of person in each "salary" levels and visualize it with a pieplot**

# %%
# Your Code is Here
df.salary.value_counts(normalize=True)
# Out:
# <=50K    0.759074
# >50K     0.240926
# Name: salary, dtype: float64

# %%
# Your Code is Here
plt.figure(figsize=(10, 8))
plt.title("Income Distrubution", fontsize = 15)

y = df["salary"].value_counts().values
labels = df["salary"].value_counts().index

explode = [0, 0.1]
plt.pie(y, labels=labels, explode=explode,  autopct="%.1f%%");

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** More than 75% of the individuals participated in the survey has income $50,000 or less.

# %% [markdown]
# ## Numeric Features

# %% [markdown]
# ## age

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x="age", data=df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.histplot(x="age", data=df, bins=(20), kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.age.describe()
# Out:
# count    32537.000000
# mean        38.585549
# std         13.637984
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.boxplot(y="age", x= "salary", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='age'>

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.histplot(x="age", data=df, hue= "salary", bins=(20), kde=True);

# %%
# Your Code is Here


plt.figure(figsize=(10,6))
sns.kdeplot(x="age", data=df, hue= "salary", shade=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").describe()["age"]
# Out:
#           count       mean        std   min   25%   50%   75%   max
# salary
# <=50K   24698.0  36.787392  14.017335  17.0  25.0  34.0  46.0  90.0
# >50K     7839.0  44.250925  10.520102  19.0  36.0  44.0  51.0  90.0

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** For those earn above 50K the mean and the meadian is higher than for those earn 50K or less. While age distribution is right skewed for participants who get 50K or less, for those who earn above 50K age looks like normally distributed.

# %% [markdown]
# ## fnlwgt
#
# ## NOTE: "fnlwgt" IS A WEIGHTING VARIABLE. THEREFORE THE FOLLOWING ANALYSES ARE NOT VALID. HOWEVER, FOR THE PURPOSE OF PRACTICE AND ASSIGNMENT I CODED THE FOLLOWINGS.

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.boxplot(x="fnlwgt", data=df)
# Out:
# <AxesSubplot:xlabel='fnlwgt'>

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.kdeplot(x="fnlwgt", data=df, shade=True);

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.fnlwgt.describe()
# Out:
# count    3.253700e+04
# mean     1.897808e+05
# std      1.055565e+05
# min      1.228500e+04
# 25%      1.178270e+05
# 50%      1.783560e+05
# 75%      2.369930e+05
# max      1.484705e+06
# Name: fnlwgt, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.boxplot(y="fnlwgt", x= "salary", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='fnlwgt'>

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.kdeplot(x="fnlwgt", data=df, hue= "salary", shade=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").describe()["fnlwgt"]
# Out:
#           count           mean            std      min       25%       50%  \
# salary
# <=50K   24698.0  190345.926796  106487.413197  12285.0  117606.0  179465.0
# >50K     7839.0  188000.480674  102554.464101  14878.0  119100.0  176063.0
#
#               75%        max
# salary
# <=50K   238968.25  1484705.0
# >50K    230969.00  1226583.0

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** No analysis, nor conclusion can be made since "fnlwgt" is a weighting variable. "fnlwgt: this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights. "

# %% [markdown]
# ## capital_gain

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x="capital_gain", data=df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(x="capital_gain", data=df, shade=True)
# Out:
# <AxesSubplot:xlabel='capital_gain', ylabel='Density'>

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.capital_gain.describe()
# Out:
# count    32537.000000
# mean      1078.443741
# std       7387.957424
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name: capital_gain, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.boxplot(y="capital_gain", x= "salary", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='capital_gain'>

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.kdeplot(x="capital_gain", data=df, hue= "salary");

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").describe()["capital_gain"]
# Out:
#           count         mean           std  min  25%  50%  75%      max
# salary
# <=50K   24698.0   148.884970    963.557955  0.0  0.0  0.0  0.0  41310.0
# >50K     7839.0  4007.164562  14572.097223  0.0  0.0  0.0  0.0  99999.0

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_gain not equal the zero**

# %%
# Your Code is Here

df.loc[df["capital_gain"] != 0].groupby("salary").describe()["capital_gain"]
# Out:
#          count         mean           std     min     25%     50%      75%  \
# salary
# <=50K   1035.0   3552.81256   3173.419287   114.0  2202.0  3273.0   4101.0
# >50K    1677.0  18731.16458  26778.676066  3103.0  7298.0  7896.0  15024.0
#
#             max
# salary
# <=50K   41310.0
# >50K    99999.0

# %%
print(1035/24698)

print(1677/7839)
# Out:
# 0.04190622722487651
# 0.21393034825870647

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Capital gain refers to a profit from the sale of investments or property. Only about 4 percent (1035/24698 = 0.042) of those earn less than 50K have some profit their investments. On the other hand about 21 percent of those earn above 50K have some profit from the sale of their investments. The anlysis show that those who earn 50K or less either do not have sufficient income to make investments or do ot have capacity to make profitable investments. The average capital gain for the low income group is 3552.8 USD, and 18731.2 USD for the latter (means provided for only those who have some positive gains).

# %% [markdown]
# # capital_loss

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x="capital_loss", data=df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(x="capital_loss", data=df, shade=True)
# Out:
# <AxesSubplot:xlabel='capital_loss', ylabel='Density'>

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.capital_loss.describe()
# Out:
# count    32537.000000
# mean        87.368227
# std        403.101833
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       4356.000000
# Name: capital_loss, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.boxplot(y="capital_loss", x= "salary", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='capital_loss'>

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.kdeplot(x="capital_loss", data=df, hue= "salary", shade=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").describe()["capital_loss"]
# Out:
#           count        mean         std  min  25%  50%  75%     max
# salary
# <=50K   24698.0   53.190258  310.890099  0.0  0.0  0.0  0.0  4356.0
# >50K     7839.0  195.051282  595.555395  0.0  0.0  0.0  0.0  3683.0

# %% [markdown]
# **Check the statistical values by "salary" levels for capital_loss not equel the zero**

# %%
# Your Code is Here

df.loc[df["capital_loss"] != 0].groupby("salary").describe()["capital_loss"]
# Out:
#         count         mean         std    min     25%     50%     75%     max
# salary
# <=50K   746.0  1760.982574  438.906164  155.0  1590.0  1721.0  1980.0  4356.0
# >50K    773.0  1978.016818  264.143642  653.0  1887.0  1902.0  1977.0  3683.0

# %%
print(746/24698)
print(773/7839)
# Out:
# 0.03020487488865495
# 0.09860951651996427

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Capital loss refers to a loss from the sale of investments or property. Only about 3 percent (746/24698 = 0.030) of those earn less than 50K have some loss from the sale of their investments. On the other hand about 10 percent of those earn above 50K have some loss from the sale of their investments. The average capital loss for the low income group is 1760.98 USD, and 1978.02 USD for the latter (means provided for only those who have some positive gains).

# %% [markdown]
# ## hours_per_week

# %% [markdown]
# **Check the boxplot to see extreme values**

# %%
# Your Code is Here

sns.boxplot(x="hours_per_week", data=df);

# %% [markdown]
# **Check the histplot/kdeplot to see distribution of feature**

# %%
# Your Code is Here

sns.kdeplot(x="hours_per_week", data=df, shade=True)
# Out:
# <AxesSubplot:xlabel='hours_per_week', ylabel='Density'>

# %% [markdown]
# **Check the statistical values**

# %%
# Your Code is Here

df.hours_per_week.describe()
# Out:
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# **Check the boxplot and histplot/kdeplot by "salary" levels**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.boxplot(y="hours_per_week", x= "salary", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='hours_per_week'>

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
sns.kdeplot(x="hours_per_week", data=df, hue= "salary", shade=True);

# %% [markdown]
# **Check the statistical values by "salary" levels**

# %%
# Your Code is Here

df.groupby("salary").describe()["hours_per_week"]
# Out:
#           count       mean        std  min   25%   50%   75%   max
# salary
# <=50K   24698.0  38.842862  12.318286  1.0  35.0  40.0  40.0  99.0
# >50K     7839.0  45.473402  11.014165  1.0  40.0  40.0  50.0  99.0

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Average work hour for those earn above 50K is considerably higher than those make 50K or less. The means are 45.5 hours and 38.8 hours respectively. The sd is lower for the 50K plus group (11.01 vs. 12.31) which tells us the distribution is closer to the mean.

# %% [markdown]
# ### See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
# Your Code is Here

sns.pairplot(df, hue="salary", palette="winter", corner=True);

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# ## education & education_num

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df.education.value_counts()
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
# Your Code is Here

df.education_num.value_counts()
# Out:
# 9.0     10208
# 10.0     7089
# 13.0     5245
# 14.0     1686
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       630
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       329
# 2.0       159
# 1.0        49
# Name: education_num, dtype: int64

# %%
# Your Code is Here

df.education_num.groupby([df["education"]]).value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.0                916
#               NaN                 17
# 11th          7.0               1146
#               NaN                 29
# 12th          8.0                424
#               NaN                  9
# 1st-4th       2.0                159
#               NaN                  7
# 5th-6th       3.0                329
#               NaN                  3
# 7th-8th       4.0                630
#               NaN                 15
# 9th           5.0                503
#               NaN                 11
# Assoc-acdm    12.0              1044
#               NaN                 23
# Assoc-voc     11.0              1343
#               NaN                 39
# Bachelors     13.0              5245
#               NaN                108
# Doctorate     16.0               405
#               NaN                  8
# HS-grad       9.0              10208
#               NaN                286
# Masters       14.0              1686
#               NaN                 36
# Preschool     1.0                 49
#               NaN                  1
# Prof-school   15.0               559
#               NaN                 17
# Some-college  10.0              7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [raw]
# Desired Output:
#
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              159
#               NaN                  7
# 5th-6th       3.000              329
#               NaN                  3
# 7th-8th       4.000              630
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5245
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10208
#               NaN                286
# Masters       14.000            1686
#               NaN                 36
# Preschool     1.000               49
#               NaN                  1
# Prof-school   15.000             559
#               NaN                 17
# Some-college  10.000            7089
#               NaN                193
# Name: education_num, dtype: int64

# %% [markdown]
# **Visualize the count of person in each categories for these features (education, education_num) separately**

# %%
# Your Code is Here
sns.countplot(x="education", data=df)
plt.xticks(rotation = 45);

# %%
# Your Code is Here

sns.countplot(x="education_num", data=df)
plt.xticks(rotation = 45);

# %% [markdown]
# **Check the count of person in each "salary" levels by these features (education and education_num) separately and visualize them with countplot**

# %%
# Your Code is Here

df.salary.groupby(df["education"]).value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       >50K       959
#               <=50K      763
# Preschool     <=50K       50
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5896
#               >50K      1386
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x="education", data=df, hue="salary")
plt.xticks(rotation = 45);

# %%
# Your Code is Here

df.salary.groupby(df["education_num"]).value_counts()
# Out:
# education_num  salary
# 1.0            <=50K       49
# 2.0            <=50K      153
#                >50K         6
# 3.0            <=50K      313
#                >50K        16
# 4.0            <=50K      592
#                >50K        38
# 5.0            <=50K      477
#                >50K        26
# 6.0            <=50K      854
#                >50K        62
# 7.0            <=50K     1088
#                >50K        58
# 8.0            <=50K      391
#                >50K        33
# 9.0            <=50K     8579
#                >50K      1629
# 10.0           <=50K     5746
#                >50K      1343
# 11.0           <=50K      994
#                >50K       349
# 12.0           <=50K      787
#                >50K       257
# 13.0           <=50K     3078
#                >50K      2167
# 14.0           >50K       935
#                <=50K      751
# 15.0           >50K       410
#                <=50K      149
# 16.0           >50K       302
#                <=50K      103
# Name: salary, dtype: int64

# %%
# Your Code is Here

sns.countplot(x="education_num", data=df, hue="salary")
plt.xticks(rotation = 45);

# %% [markdown]
# **Visualize the boxplot of "education_num" feature by "salary" levels**

# %%
# Your Code is Here

sns.boxplot(x = "salary", y="education_num", data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='education_num'>

# %% [markdown]
# **Decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.**

# %%
def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
# Your Code is Here

df.education.transform(mapping_education)
# Out:
# 0          high_level_grade
# 1          high_level_grade
# 2        medium_level_grade
# 3           low_level_grade
# 4          high_level_grade
#                 ...
# 32556    medium_level_grade
# 32557    medium_level_grade
# 32558    medium_level_grade
# 32559    medium_level_grade
# 32560    medium_level_grade
# Name: education, Length: 32537, dtype: object

# %%
# By using "mapping_education" def function above, create a new column named "education_summary"

# Your Code is Here

df["education_summary"] = df.education.transform(mapping_education)
df.education_summary
# Out:
# 0          high_level_grade
# 1          high_level_grade
# 2        medium_level_grade
# 3           low_level_grade
# 4          high_level_grade
#                 ...
# 32556    medium_level_grade
# 32557    medium_level_grade
# 32558    medium_level_grade
# 32559    medium_level_grade
# 32560    medium_level_grade
# Name: education_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each categories for these new education levels (high, medium, low)**

# %%
plt.figure(figsize=(10,6))
plt.suptitle("N of individuals in education categories")

sns.countplot(data=df, x="education_summary", )
# Out:
# <AxesSubplot:xlabel='education_summary', ylabel='count'>

# %% [markdown]
# **Check the count of person in each "salary" levels by these new education levels(high, medium, low) and visualize it with countplot**

# %%
# Your Code is Here

df.groupby(["education_summary", "salary"]).size()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# dtype: int64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("N of individuals in education categories- separeted by salary")

sns.countplot(data=df, x="education_summary", hue="salary")
# Out:
# <AxesSubplot:xlabel='education_summary', ylabel='count'>

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new education levels (high, medium, low) and visualize it with pie plot separately**

# %%
# Your Code is Here

edu_by_sal = df["salary"].groupby(df.education_summary).value_counts(normalize=True ).round(decimals=3)
edu_by_sal
# Out:
# education_summary   salary
# high_level_grade    <=50K     0.515
#                     >50K      0.485
# low_level_grade     <=50K     0.943
#                     >50K      0.057
# medium_level_grade  <=50K     0.818
#                     >50K      0.182
# Name: salary, dtype: float64

# %%
df["salary"].groupby(df.education_summary).value_counts( )
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
edu_by_sal["high_level_grade"]
# Out:
# salary
# <=50K    0.515
# >50K     0.485
# Name: salary, dtype: float64

# %% [raw]
# Desired Output:
#
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
# Your Code is Here
fig = plt.figure(figsize=(18,9))
fig.suptitle("Education level and salary", y = 0.9, fontsize = 20)

plt.subplot(1,3,1)
plt.title("high_level_grade")
plt.pie(edu_by_sal["high_level_grade"], autopct="%.2f%%", labels=edu_by_sal["high_level_grade"].index)

plt.subplot(1,3,2)
plt.title("medium_level_grade")
plt.pie(edu_by_sal["medium_level_grade"], autopct="%.2f%%", labels=edu_by_sal["medium_level_grade"].index)

plt.subplot(1,3,3)
plt.title("low_level_grade")
plt.pie(edu_by_sal["low_level_grade"], autopct="%.2f%%", labels=edu_by_sal["low_level_grade"].index);

# %% [markdown]
# **Check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df["education_summary"].groupby(df.salary).value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %% [raw]
# Desired Output:
#
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("education and income")

sns.countplot(x = df.salary,hue=df.education_summary)

plt.xticks(rotation = 45);

# %% [markdown]
# **Check the the percentage distribution of person in each these new education levels(high, medium, low) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

sal_by_edu = df["education_summary"].groupby(df.salary).value_counts(normalize=True).round(decimals=3)
sal_by_edu
# Out:
# salary  education_summary
# <=50K   medium_level_grade    0.670
#         high_level_grade      0.168
#         low_level_grade       0.162
# >50K    high_level_grade      0.499
#         medium_level_grade    0.470
#         low_level_grade       0.031
# Name: education_summary, dtype: float64

# %%
# Your Code is Here

fig = plt.figure(figsize=(12,8))
fig.suptitle("Salary and education level", y = 0.9, fontsize = 20)

plt.subplot(1,2,1)
plt.title("<=50K")
plt.pie(sal_by_edu["<=50K"], autopct="%.2f%%", labels=sal_by_edu["<=50K"].index)

plt.subplot(1,2,2)
plt.title(">50K")
plt.pie(sal_by_edu[">50K"], autopct="%.2f%%", labels=sal_by_edu[">50K"].index);

# %%
# Your Code is Here

sal_by_edu2 = df["education_summary"].groupby(df.salary).value_counts(normalize=True).round(decimals=3).sort_index(level = ["salary",  "education_summary"])
sal_by_edu2
# Out:
# salary  education_summary
# <=50K   high_level_grade      0.168
#         low_level_grade       0.162
#         medium_level_grade    0.670
# >50K    high_level_grade      0.499
#         low_level_grade       0.031
#         medium_level_grade    0.470
# Name: education_summary, dtype: float64

# %%
# Your Code is Here

fig = plt.figure(figsize=(12,8))
fig.suptitle("Salary and education level - II", y = 0.9, fontsize = 20)

plt.subplot(1,2,1)
plt.title("<=50K")
plt.pie(sal_by_edu2["<=50K"], autopct="%.2f%%", labels=sal_by_edu2["<=50K"].index)

plt.subplot(1,2,2)
plt.title(">50K")
plt.pie(sal_by_edu2[">50K"], autopct="%.2f%%", labels=sal_by_edu2[">50K"].index);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Majority of particimants that earn more than 50K (49,9%) have high level of education, while the majority of those that make 50K or less medium level educational attaintment.

# %% [markdown]
# ## marital_status & relationship

# %% [markdown]
# **Detect the similarities between these features by comparing unique values**

# %%
# Your Code is Here

df.marital_status.value_counts(dropna=False)
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# Your Code is Here

df.relationship.value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Fill missing values with "Unknown" in the column of "relationship"

# Your Code is Here

df.relationship.fillna("Unknown", inplace=True)

# %%
# Your Code is Here

df.relationship.value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# Unknown            5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.marital_status.groupby(df.relationship).value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
#                 Married-spouse-absent       45
#                 Widowed                     15
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1600
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: marital_status, dtype: int64

# %% [markdown]
# **Assessment :** About half of the participants are married and living in a family.

# %% [markdown]
# **Visualize the count of person in each categories**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Marital ststus of the participants")

sns.countplot(data=df, x="marital_status")
plt.xticks(rotation = 45);

# %% [markdown]
# **Check the count of person in each "salary" levels by categories and visualize it with countplot**

# %%
# Your Code is Here

df.salary.groupby(df.marital_status).value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Salary by marital ststus")

ax = sns.countplot(data=df, x="marital_status", hue="salary")
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# **Decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# Your Code is Here

df.marital_status.transform(mapping_marital_status).value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %% [raw]
# Desired Output:
#
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
# By using "mapping_marital_status" def function above, create a new column named "marital_status_summary"

# Your Code is Here

df["marital_status_summary"] = df.marital_status.transform(mapping_marital_status)
df["marital_status_summary"]
# Out:
# 0        unmarried
# 1          married
# 2        unmarried
# 3          married
# 4          married
#            ...
# 32556      married
# 32557      married
# 32558    unmarried
# 32559    unmarried
# 32560      married
# Name: marital_status_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each categories for these new marital status (married, unmarried)**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("marital ststus")

ax = sns.countplot(data=df, x="marital_status_summary")
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the count of person in each "salary" levels by these new marital status (married, unmarried) and visualize it with countplot**

# %%
# Your Code is Here

df.salary.groupby(df.marital_status_summary).value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Salary by marital ststus")

ax = sns.countplot(data=df, x="marital_status_summary", hue="salary")
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new marital status (married, unmarried) and visualize it with pie plot separately**

# %%
# Your Code is Here

sal_by_mar = df.salary.groupby(df.marital_status_summary).value_counts("normalize").round(decimals=3)
sal_by_mar
# Out:
# marital_status_summary  salary
# married                 <=50K     0.563
#                         >50K      0.437
# unmarried               <=50K     0.935
#                         >50K      0.065
# Name: salary, dtype: float64

# %%
# Your Code is Here

fig = plt.figure(figsize=(12,8))
fig.suptitle("Salary and marital status", y = 0.9, fontsize = 20)

plt.subplot(1,2,1)
plt.title("married")
plt.pie(sal_by_mar["married"], autopct="%.2f%%", labels=sal_by_mar["married"].index)

plt.subplot(1,2,2)
plt.title("unmarried")
plt.pie(sal_by_mar["unmarried"], autopct="%.2f%%", labels=sal_by_mar["unmarried"].index);

# %% [markdown]
# **Check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.marital_status_summary.groupby(df.salary).value_counts()
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Salary by marital ststus")

ax =sns.countplot(data=df, x="salary", hue="marital_status_summary")
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the the percentage distribution of person in each these new marital status (married, unmarried) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

sal_by_mar2 = df.marital_status_summary.groupby(df.salary).value_counts(normalize=True).round(decimals=3)
sal_by_mar2
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 0.649
#         married                   0.351
# >50K    married                   0.859
#         unmarried                 0.141
# Name: marital_status_summary, dtype: float64

# %%
# Your Code is Here

df_m_s = pd.DataFrame(df.marital_status_summary.groupby(df.salary).value_counts(normalize=True).round(decimals=3))

df_m_s["percent"] = df_m_s.values
df_m_s.drop("marital_status_summary", axis=1, inplace=True)
df_m_s.reset_index(inplace=True)
df_m_s
# Out:
#   salary marital_status_summary  percent
# 0  <=50K              unmarried    0.649
# 1  <=50K                married    0.351
# 2   >50K                married    0.859
# 3   >50K              unmarried    0.141

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Swb4rb7/v53.png)

# %%
# Your Code is Here

fig = plt.figure(figsize=(12,8))
fig.suptitle("Salary and marital status II", y = 0.9, fontsize = 20)

plt.subplot(1,2,1)
plt.title("<=50K")
plt.pie(sal_by_mar2["<=50K"], autopct="%.2f%%", labels=sal_by_mar2["<=50K"].index)

plt.subplot(1,2,2)
plt.title(">50K")
plt.pie(sal_by_mar2[">50K"], autopct="%.2f%%", labels=sal_by_mar2[">50K"].index);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Majority of the group (85.9%) that make more than 50K are married.

# %% [markdown]
# ## workclass

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.workclass.value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Work class")

ax = sns.countplot(data=df, x="workclass")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unkown"

# Your Code is Here

df.workclass.replace("?","Unknown", inplace=True)

# %%
df.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %% [markdown]
# **Check the count of person in each "salary" levels by workclass groups and visualize it with countplot**

# %%
# Your Code is Here

df.salary.groupby(df.workclass).value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Work class")

ax = sns.countplot(data=df, x="workclass", hue="salary")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each workclass groups and visualize it with bar plot**

# %%
# Your Code is Here

df.salary.groupby(df.workclass).value_counts("normalize").round(decimals=3)
# Out:
# workclass         salary
# Federal-gov       <=50K     0.614
#                   >50K      0.386
# Local-gov         <=50K     0.705
#                   >50K      0.295
# Never-worked      <=50K     1.000
# Private           <=50K     0.781
#                   >50K      0.219
# Self-emp-inc      >50K      0.557
#                   <=50K     0.443
# Self-emp-not-inc  <=50K     0.715
#                   >50K      0.285
# State-gov         <=50K     0.728
#                   >50K      0.272
# Unknown           <=50K     0.896
#                   >50K      0.104
# Without-pay       <=50K     1.000
# Name: salary, dtype: float64

# %%
# Your Code is Here

df_w_s = pd.DataFrame(df.salary.groupby(df.workclass).value_counts("normalize").round(decimals=3))

df_w_s["percent"] = df_w_s.values
df_w_s.drop("salary", axis=1, inplace=True)
df_w_s.reset_index(inplace=True)
df_w_s
# Out:
#            workclass salary  percent
# 0        Federal-gov  <=50K    0.614
# 1        Federal-gov   >50K    0.386
# 2          Local-gov  <=50K    0.705
# 3          Local-gov   >50K    0.295
# 4       Never-worked  <=50K    1.000
# 5            Private  <=50K    0.781
# 6            Private   >50K    0.219
# 7       Self-emp-inc   >50K    0.557
# 8       Self-emp-inc  <=50K    0.443
# 9   Self-emp-not-inc  <=50K    0.715
# 10  Self-emp-not-inc   >50K    0.285
# 11         State-gov  <=50K    0.728
# 12         State-gov   >50K    0.272
# 13           Unknown  <=50K    0.896
# 14           Unknown   >50K    0.104
# 15       Without-pay  <=50K    1.000

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Work class")

ax = sns.barplot(data=df_w_s, x="workclass", y="percent", hue="salary")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/NFN5q04/58.png)

# %% [markdown]
# **Check the count of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here


df.workclass.groupby(df.salary).value_counts()
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Work class")

ax = sns.countplot(data=df, x="salary", hue="workclass")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the the percentage distribution of person in each workclass groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.workclass.groupby(df.salary).value_counts("normalize").round(decimals=3)
# Out:
# salary  workclass
# <=50K   Private             0.717
#         Self-emp-not-inc    0.074
#         Unknown             0.067
#         Local-gov           0.060
#         State-gov           0.038
#         Federal-gov         0.024
#         Self-emp-inc        0.020
#         Without-pay         0.001
#         Never-worked        0.000
# >50K    Private             0.633
#         Self-emp-not-inc    0.092
#         Self-emp-inc        0.079
#         Local-gov           0.079
#         Federal-gov         0.047
#         State-gov           0.045
#         Unknown             0.024
# Name: workclass, dtype: float64

# %%
# Your Code is Here

df_s_w = pd.DataFrame(df.workclass.groupby(df.salary).value_counts("normalize").round(decimals=3))

df_s_w["percent"] = df_s_w.values
df_s_w.drop("workclass", axis=1, inplace=True)
df_s_w.reset_index(inplace=True)
df_s_w
# Out:
#    salary         workclass  percent
# 0   <=50K           Private    0.717
# 1   <=50K  Self-emp-not-inc    0.074
# 2   <=50K           Unknown    0.067
# 3   <=50K         Local-gov    0.060
# 4   <=50K         State-gov    0.038
# 5   <=50K       Federal-gov    0.024
# 6   <=50K      Self-emp-inc    0.020
# 7   <=50K       Without-pay    0.001
# 8   <=50K      Never-worked    0.000
# 9    >50K           Private    0.633
# 10   >50K  Self-emp-not-inc    0.092
# 11   >50K      Self-emp-inc    0.079
# 12   >50K         Local-gov    0.079
# 13   >50K       Federal-gov    0.047
# 14   >50K         State-gov    0.045
# 15   >50K           Unknown    0.024

# %%
# Your Code is Here

plt.figure(figsize=(14,6))
plt.suptitle("Work class")

ax = sns.barplot(data=df_s_w, x="salary", y="percent", hue="workclass",  )
plt.xticks(rotation = 45)
plt.legend(loc='upper right')
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Kz5BDBj/61.png)

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** The share of Federal, state and local government workers and self-employed individuals are relatively higher for the category of income above 50K.

# %% [markdown]
# ## occupation

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Occupation ststus of the participants")

sns.countplot(x="occupation", data=df)
plt.xticks(rotation = 90);

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df.occupation.replace("?","Unknown", inplace=True)

# %% [markdown]
# **Check the count of person in each "salary" levels by occupation groups and visualize it with countplot**

# %%
# Your Code is Here

df.salary.groupby(df.occupation).value_counts()
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
#                    >50K       320
# Unknown            <=50K     1652
#                    >50K       191
# Name: salary, dtype: int64

# %%
# Your Code is Here
plt.figure(figsize=(10,6))
plt.suptitle("Occupation and Salary")

ax = sns.countplot(data=df, x="occupation", hue="salary")
plt.xticks(rotation = 90)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each occupation groups and visualize it with bar plot**

# %%
# Your Code is Here

df.salary.groupby(df.occupation).value_counts("normalize").round(decimals=3)
# Out:
# occupation         salary
# Adm-clerical       <=50K     0.865
#                    >50K      0.135
# Armed-Forces       <=50K     0.889
#                    >50K      0.111
# Craft-repair       <=50K     0.773
#                    >50K      0.227
# Exec-managerial    <=50K     0.516
#                    >50K      0.484
# Farming-fishing    <=50K     0.884
#                    >50K      0.116
# Handlers-cleaners  <=50K     0.937
#                    >50K      0.063
# Machine-op-inspct  <=50K     0.876
#                    >50K      0.124
# Other-service      <=50K     0.958
#                    >50K      0.042
# Priv-house-serv    <=50K     0.993
#                    >50K      0.007
# Prof-specialty     <=50K     0.551
#                    >50K      0.449
# Protective-serv    <=50K     0.675
#                    >50K      0.325
# Sales              <=50K     0.731
#                    >50K      0.269
# Tech-support       <=50K     0.695
#                    >50K      0.305
# Transport-moving   <=50K     0.800
#                    >50K      0.200
# Unknown            <=50K     0.896
#                    >50K      0.104
# Name: salary, dtype: float64

# %%
# Your Code is Here
df_o_s = pd.DataFrame(df.salary.groupby(df.occupation).value_counts("normalize").round(decimals=3))

df_o_s["percent"] = df_o_s.values
df_o_s.drop("salary", axis=1, inplace=True)
df_o_s.reset_index(inplace=True)
df_o_s
# Out:
#            occupation salary  percent
# 0        Adm-clerical  <=50K    0.865
# 1        Adm-clerical   >50K    0.135
# 2        Armed-Forces  <=50K    0.889
# 3        Armed-Forces   >50K    0.111
# 4        Craft-repair  <=50K    0.773
# 5        Craft-repair   >50K    0.227
# 6     Exec-managerial  <=50K    0.516
# 7     Exec-managerial   >50K    0.484
# 8     Farming-fishing  <=50K    0.884
# 9     Farming-fishing   >50K    0.116
# 10  Handlers-cleaners  <=50K    0.937
# 11  Handlers-cleaners   >50K    0.063
# 12  Machine-op-inspct  <=50K    0.876
# 13  Machine-op-inspct   >50K    0.124
# 14      Other-service  <=50K    0.958
# 15      Other-service   >50K    0.042
# 16    Priv-house-serv  <=50K    0.993
# 17    Priv-house-serv   >50K    0.007
# 18     Prof-specialty  <=50K    0.551
# 19     Prof-specialty   >50K    0.449
# 20    Protective-serv  <=50K    0.675
# 21    Protective-serv   >50K    0.325
# 22              Sales  <=50K    0.731
# 23              Sales   >50K    0.269
# 24       Tech-support  <=50K    0.695
# 25       Tech-support   >50K    0.305
# 26   Transport-moving  <=50K    0.800
# 27   Transport-moving   >50K    0.200
# 28            Unknown  <=50K    0.896
# 29            Unknown   >50K    0.104

# %%
# Your Code is Here
plt.figure(figsize=(14,7))
plt.suptitle("Occupation and Salary")

ax = sns.barplot(data=df_o_s, x="occupation", y="percent", hue="salary")
plt.xticks(rotation = 90)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the count of person in each occupation groups by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.occupation.groupby(df.salary).value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknown              1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
#         Handlers-cleaners      86
#         Armed-Forces            1
#         Priv-house-serv         1
# Name: occupation, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(14,6))
plt.suptitle("Occupation")

ax = sns.countplot(data=df, x="salary", hue="occupation",edgecolor = "black")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/cvHS3FH/66.png)

# %% [markdown]
# **Check the the percentage distribution of person in each occupation groups by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.occupation.groupby(df.salary).value_counts("normalize").round(decimals=3)
# Out:
# salary  occupation
# <=50K   Adm-clerical         0.132
#         Craft-repair         0.128
#         Other-service        0.128
#         Sales                0.108
#         Prof-specialty       0.092
#         Exec-managerial      0.085
#         Machine-op-inspct    0.071
#         Unknown              0.067
#         Handlers-cleaners    0.052
#         Transport-moving     0.052
#         Farming-fishing      0.036
#         Tech-support         0.026
#         Protective-serv      0.018
#         Priv-house-serv      0.006
#         Armed-Forces         0.000
# >50K    Exec-managerial      0.251
#         Prof-specialty       0.237
#         Sales                0.125
#         Craft-repair         0.119
#         Adm-clerical         0.065
#         Transport-moving     0.041
#         Tech-support         0.036
#         Machine-op-inspct    0.032
#         Protective-serv      0.027
#         Unknown              0.024
#         Other-service        0.017
#         Farming-fishing      0.015
#         Handlers-cleaners    0.011
#         Armed-Forces         0.000
#         Priv-house-serv      0.000
# Name: occupation, dtype: float64

# %%
# Your Code is Here

df_s_o = pd.DataFrame(df.occupation.groupby(df.salary).value_counts("normalize").round(decimals=3))

df_s_o["percent"] = df_s_o.values
df_s_o.drop("occupation", axis=1, inplace=True)
df_s_o.reset_index(inplace=True)
df_s_o
# Out:
#    salary         occupation  percent
# 0   <=50K       Adm-clerical    0.132
# 1   <=50K       Craft-repair    0.128
# 2   <=50K      Other-service    0.128
# 3   <=50K              Sales    0.108
# 4   <=50K     Prof-specialty    0.092
# 5   <=50K    Exec-managerial    0.085
# 6   <=50K  Machine-op-inspct    0.071
# 7   <=50K            Unknown    0.067
# 8   <=50K  Handlers-cleaners    0.052
# 9   <=50K   Transport-moving    0.052
# 10  <=50K    Farming-fishing    0.036
# 11  <=50K       Tech-support    0.026
# 12  <=50K    Protective-serv    0.018
# 13  <=50K    Priv-house-serv    0.006
# 14  <=50K       Armed-Forces    0.000
# 15   >50K    Exec-managerial    0.251
# 16   >50K     Prof-specialty    0.237
# 17   >50K              Sales    0.125
# 18   >50K       Craft-repair    0.119
# 19   >50K       Adm-clerical    0.065
# 20   >50K   Transport-moving    0.041
# 21   >50K       Tech-support    0.036
# 22   >50K  Machine-op-inspct    0.032
# 23   >50K    Protective-serv    0.027
# 24   >50K            Unknown    0.024
# 25   >50K      Other-service    0.017
# 26   >50K    Farming-fishing    0.015
# 27   >50K  Handlers-cleaners    0.011
# 28   >50K       Armed-Forces    0.000
# 29   >50K    Priv-house-serv    0.000

# %%
# Your Code is Here

plt.figure(figsize=(16,8))
plt.suptitle("Occupation")

ax = sns.barplot(data=df_s_o, x="salary", y="percent", hue="occupation", edgecolor="black" )
plt.xticks(rotation = 90)
plt.legend(loc='upper right')
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** Individuals in Exec-managerial (25.1%), Prof-specialty (23,7%), Sales	(12,5%) and Craft-repair (11,9%)   occupational categories have relatively higher representations in 50K plus salary group.

# %% [markdown]
# ## race

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.race.value_counts()
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Race")

ax = sns.countplot(data=df, x="race")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the count of person in each "salary" levels by races and visualize it with countplot**

# %%
# Your Code is Here

df.salary.groupby(df.race).value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Race")

ax = sns.countplot(data=df, x="race", hue="salary")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot**

# %%
# Your Code is Here

df_s_r = df.salary.groupby(df.race).value_counts("normalize").round(decimals=3)
df_s_r
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K     0.884
#                     >50K      0.116
# Asian-Pac-Islander  <=50K     0.734
#                     >50K      0.266
# Black               <=50K     0.876
#                     >50K      0.124
# Other               <=50K     0.908
#                     >50K      0.092
# White               <=50K     0.744
#                     >50K      0.256
# Name: salary, dtype: float64

# %%
fig = plt.figure(figsize=(18,14))
fig.suptitle("Salary and Race", y = 0.9, fontsize = 20)

plt.subplot(2,3,1)
plt.title("Amer-Indian-Eskimo")
plt.pie(df_s_r["Amer-Indian-Eskimo"], autopct="%.2f%%", labels=df_s_r["Amer-Indian-Eskimo"].index)

plt.subplot(2,3,2)
plt.title("Asian-Pac-Islander")
plt.pie(df_s_r["Asian-Pac-Islander"], autopct="%.2f%%", labels=df_s_r["Asian-Pac-Islander"].index)

plt.subplot(2,3,3)
plt.title("Black")
plt.pie(df_s_r["Black"], autopct="%.2f%%", labels=df_s_r["Black"].index)

plt.subplot(2,3,4)
plt.title("Other")
plt.pie(df_s_r["Other"], autopct="%.2f%%", labels=df_s_r["Other"].index)

plt.subplot(2,3,5)
plt.title("White")
plt.pie(df_s_r["White"], autopct="%.2f%%", labels=df_s_r["White"].index);

# %%
# Your Code is Here


# y= pd.DataFrame(df.salary.groupby(df.race).value_counts(normalize=True).unstack(level=0))

# ax = y.plot.pie(subplots=True, figsize=[18,12], autopct='%1.2f%%',legend=False, colors=colors, startangle=0);

# %% [markdown]
# **Check the count of person in each races by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.race.groupby(df.salary).value_counts()
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("race and salary")

ax = sns.countplot(data=df, x="salary", hue="race")
plt.xticks(rotation = 90)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the the percentage distribution of person in each races by "salary" levels and visualize it with bar plot**

# %%
# Your Code is Here

df.race.groupby(df.salary).value_counts("normalize").round(decimals=3)
# Out:
# salary  race
# <=50K   White                 0.837
#         Black                 0.111
#         Asian-Pac-Islander    0.031
#         Amer-Indian-Eskimo    0.011
#         Other                 0.010
# >50K    White                 0.908
#         Black                 0.049
#         Asian-Pac-Islander    0.035
#         Amer-Indian-Eskimo    0.005
#         Other                 0.003
# Name: race, dtype: float64

# %%
# Your Code is Here

df_r_s = pd.DataFrame(df.race.groupby(df.salary).value_counts("normalize").round(decimals=3))

df_r_s["percent"] = df_r_s.values
df_r_s.drop("race", axis=1, inplace=True)
df_r_s.reset_index(inplace=True)
df_r_s
# Out:
#   salary                race  percent
# 0  <=50K               White    0.837
# 1  <=50K               Black    0.111
# 2  <=50K  Asian-Pac-Islander    0.031
# 3  <=50K  Amer-Indian-Eskimo    0.011
# 4  <=50K               Other    0.010
# 5   >50K               White    0.908
# 6   >50K               Black    0.049
# 7   >50K  Asian-Pac-Islander    0.035
# 8   >50K  Amer-Indian-Eskimo    0.005
# 9   >50K               Other    0.003

# %%
# Your Code is Here

plt.figure(figsize=(14,6))
plt.suptitle("race and salary")

ax = sns.barplot(data=df_r_s, x="salary", y="percent", hue="race")
plt.xticks(rotation = 90)
plt.legend(loc='upper right')
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** 25.6% of whites and 26.6% of Asian-Pac-Islanders have income over 50K, compared to 12.4% of Blacks, 11.6% of Amer-Indian-Eskimo  and 9.2% of Others. Race seems to be a factor in salary.

# %% [markdown]
# ## gender

# %% [markdown]
# **Check the count of person in each gender and visualize it with countplot**

# %%
# Your Code is Here

df.sex.value_counts()
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Gender distribution")

ax = sns.countplot(data=df, x="sex")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the count of person in each "salary" levels by gender and visualize it with countplot**

# %%
# Your Code is Here

df.salary.groupby(df.sex).value_counts()
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("sex")

ax = sns.countplot(data=df, x="sex", hue="salary")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot**

# %%
# Your Code is Here

df_s_sex = df.salary.groupby(df.sex).value_counts("normalize").round(decimals=3)
df_s_sex
# Out:
# sex     salary
# Female  <=50K     0.890
#         >50K      0.110
# Male    <=50K     0.694
#         >50K      0.306
# Name: salary, dtype: float64

# %%
# Your Code is Here

fig = plt.figure(figsize=(12,8))
fig.suptitle("Salary and Gender", y = 0.9, fontsize = 20)

plt.subplot(1,2,1)
plt.title("Female")
plt.pie(df_s_sex["Female"], autopct="%.2f%%", labels=df_s_sex["Female"].index)

plt.subplot(1,2,2)
plt.title("Male")
plt.pie(df_s_sex["Male"], autopct="%.2f%%", labels=df_s_sex["Male"].index);

# %% [markdown]
# **Check the count of person in each gender by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.sex.groupby(df.salary).value_counts()
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Gender and salary")

ax = sns.countplot(data=df, x="salary", hue="sex")
plt.xticks(rotation = 90)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the the percentage distribution of person in each gender by "salary" levels and visualize it with pie plot**

# %%
# Your Code is Here

df_s_sex_1 = df.sex.groupby(df.salary).value_counts("normalize").round(decimals=3)
df_s_sex_1
# Out:
# salary  sex
# <=50K   Male      0.612
#         Female    0.388
# >50K    Male      0.850
#         Female    0.150
# Name: sex, dtype: float64

# %%
# Your Code is Here

fig = plt.figure(figsize=(12,8))
fig.suptitle("Salary and Gender", y = 0.9, fontsize = 20)

plt.subplot(1,2,1)
plt.title("<=50K")
plt.pie(df_s_sex_1["<=50K"], autopct="%.2f%%", labels=df_s_sex_1["<=50K"].index)

plt.subplot(1,2,2)
plt.title(">50K")
plt.pie(df_s_sex_1[">50K"], autopct="%.2f%%", labels=df_s_sex_1[">50K"].index);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** 11% of females earn above 50K compared to 30,6% of males, about 3 times lower ratio on females side. From salary perspective, of those that get 50K or more, males dominate the category by 85% compared to only 15% females.

# %% [markdown]
# ## native_country

# %% [markdown]
# **Check the count of person in each categories and visualize it with countplot**

# %%
# Your Code is Here

df.native_country.value_counts()
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native_country, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(20,6))
plt.suptitle("native_country")

ax = sns.countplot(data=df, x="native_country")
plt.xticks(rotation = 90)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x3TNT7B/80.png)

# %% [markdown]
# **Replace the value "?" to the value "Unknown"**

# %%
# Replace "?" values with "Unknown"

# Your Code is Here

df.native_country.replace("?","Unknown", inplace=True)

# %% [markdown]
# **Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data**

# %%
def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
# Your Code is Here

df.native_country.transform(mapping_native_country).value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country, dtype: int64

# %%
# By using "mapping_native_country" def function above, create a new column named "native_country_summary"

# Your Code is Here

df["native_country_summary"] = df.native_country.transform(mapping_native_country)
df["native_country_summary"]
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %% [markdown]
# **Visualize the count of person in each new categories (US, Others)**

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Native Country")

ax = sns.countplot(data=df, x="native_country_summary")
plt.xticks(rotation = 0)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the count of person in each "salary" levels by these new native countries (US, Others) and visualize it with countplot**

# %%
# Your Code is Here

df.salary.groupby(df.native_country_summary).value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("native_country_summary")

ax = sns.countplot(data=df, x="native_country_summary", hue="salary")
plt.xticks(rotation = 0)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately**

# %%
# Your Code is Here

df_ntv = df.salary.groupby(df.native_country_summary).value_counts("normalize").round(decimals=3)
df_ntv
# Out:
# native_country_summary  salary
# Others                  <=50K     0.802
#                         >50K      0.198
# US                      <=50K     0.754
#                         >50K      0.246
# Name: salary, dtype: float64

# %%
# Your Code is Here

fig = plt.figure(figsize=(18,14))
fig.suptitle("Salary and Native Country", y = 0.9, fontsize = 20)

plt.subplot(2,3,1)
plt.title("Others ")
plt.pie(df_ntv["Others"], autopct="%.2f%%", labels=df_ntv["Others"].index)

plt.subplot(2,3,2)
plt.title("US")
plt.pie(df_ntv["US"], autopct="%.2f%%", labels=df_ntv["US"].index);

# %% [markdown]
# **Check the count of person in each these new native countries (US, Others) by "salary" levels and visualize it with countplot**

# %%
# Your Code is Here

df.native_country_summary.groupby(df.salary).value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Race")

ax = sns.countplot(data=df, x="native_country_summary", hue="salary")
plt.xticks(rotation = 45)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# **Check the the percentage distribution of person in each these new native countries (US, Others) by "salary" levels and visualize it with pie plot separately**

# %%
# Your Code is Here

df_ntv2 = df.native_country_summary.groupby(df.salary).value_counts ("normalize").round(decimals=3)
df_ntv2
# Out:
# salary  native_country_summary
# <=50K   US                        0.890
#         Others                    0.110
# >50K    US                        0.915
#         Others                    0.085
# Name: native_country_summary, dtype: float64

# %%
# Your Code is Here

fig = plt.figure(figsize=(12,8))
fig.suptitle("Salary and marital status II", y = 0.9, fontsize = 20)

plt.subplot(1,2,1)
plt.title("<=50K")
plt.pie(df_ntv2["<=50K"], autopct="%.2f%%", labels=df_ntv2["<=50K"].index)

plt.subplot(1,2,2)
plt.title(">50K")
plt.pie(df_ntv2[">50K"], autopct="%.2f%%", labels=df_ntv2[">50K"].index);

# %% [markdown]
# **Write down the conclusions you draw from your analysis**

# %% [markdown]
# **Result :** While 19.8% of foreign nationals are paid over 50K, this percentage is 24,6 for US nationals.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
# Your Code is Here

df.groupby(["salary", "sex"]).mean()["age"].round(decimals=3)
# Out:
# salary  sex
# <=50K   Female    36.217
#         Male      37.149
# >50K    Female    42.126
#         Male      44.627
# Name: age, dtype: float64

# %%
a_g_s = pd.DataFrame(df.groupby(["salary", "sex"]).mean()["age"].round(decimals=3))
a_g_s.reset_index(inplace=True)
a_g_s["gender_salary"] = a_g_s["sex"] + a_g_s["salary"]
a_g_s
# Out:
#   salary     sex     age gender_salary
# 0  <=50K  Female  36.217   Female<=50K
# 1  <=50K    Male  37.149     Male<=50K
# 2   >50K  Female  42.126    Female>50K
# 3   >50K    Male  44.627      Male>50K

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Gender, Salary and Age (mean)")

ax = sns.barplot(data = a_g_s, x = "gender_salary", y = "age")

plt.xticks(rotation = 90)
plt.bar_label(container, fmt="%.0f", fontsize=12)
for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/BBDy081/86.png)

# %%
# Your Code is Here

a_g_s
# Out:
#   salary     sex     age gender_salary
# 0  <=50K  Female  36.217   Female<=50K
# 1  <=50K    Male  37.149     Male<=50K
# 2   >50K  Female  42.126    Female>50K
# 3   >50K    Male  44.627      Male>50K

# %%
# Your Code is Here


plt.figure(figsize=(10,6))
plt.suptitle("Gender, Salary and Age (mean)")

ax = sns.barplot(data = a_g_s, x = "salary", y = "age", hue="sex")

plt.xticks(rotation = 90)

for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
# Your Code is Here

class_income = df.workclass[df.salary == ">50K"].value_counts("normalize").round(decimals=5)*100
class_income
# Out:
# Private             63.286
# Self-emp-not-inc     9.236
# Self-emp-inc         7.935
# Local-gov            7.871
# Federal-gov          4.733
# State-gov            4.503
# Unknown              2.437
# Name: workclass, dtype: float64

# %% [raw]
# Desired Output:
#
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknown             2.455
# Name: workclass, dtype: float64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Work_class distribution among High income group")

ax = sns.barplot( x = class_income.index, y = class_income.values)

plt.xticks(rotation = 90)

for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/gMHzLgH/89.png)

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
# Your Code is Here

occupation_class = df.occupation[(df.workclass == "Private") & (df.salary == ">50K")].value_counts("normalize").round(decimals=5)*100
occupation_class
# Out:
# Exec-managerial      26.104
# Prof-specialty       20.298
# Craft-repair         14.533
# Sales                13.788
# Adm-clerical          6.470
# Transport-moving      5.120
# Machine-op-inspct     4.515
# Tech-support          4.455
# Other-service         2.016
# Handlers-cleaners     1.471
# Farming-fishing       0.605
# Protective-serv       0.605
# Priv-house-serv       0.020
# Name: occupation, dtype: float64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("Occupation distribution among High income group in private class")

ax = sns.barplot( x = occupation_class.index, y = occupation_class.values)

plt.xticks(rotation = 90)

for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
# Your Code is Here

education_class = df.education[(df.race == "Asian-Pac-Islander") & (df.salary == ">50K")].value_counts("normalize").round(decimals=5)*100
education_class
# Out:
# Bachelors       35.145
# Masters         15.580
# HS-grad         12.319
# Some-college    11.957
# Prof-school      9.783
# Doctorate        6.522
# Assoc-voc        3.261
# Assoc-acdm       2.899
# 5th-6th          1.087
# 9th              0.362
# 11th             0.362
# 10th             0.362
# 12th             0.362
# Name: education, dtype: float64

# %%
# Your Code is Here

plt.figure(figsize=(10,6))
plt.suptitle("ducation level percentages of Asian-Pac-Islander race group in high-level income group")

ax = sns.barplot( x = education_class.index, y = education_class.values)

plt.xticks(rotation = 90)

for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
# Your Code is Here

occupation_class_2 = df.occupation[(df.race == "Asian-Pac-Islander")& (df.education == "Bachelors") & (df.salary == ">50K")].value_counts("normalize").round(decimals=5)*100
occupation_class_2
# Out:
# Exec-managerial      27.835
# Prof-specialty       25.773
# Adm-clerical         12.371
# Sales                 9.278
# Other-service         9.278
# Craft-repair          7.216
# Tech-support          3.093
# Protective-serv       2.062
# Transport-moving      1.031
# Machine-op-inspct     1.031
# Farming-fishing       1.031
# Name: occupation, dtype: float64

# %%
# Your Code is Here


plt.figure(figsize=(10,6))
plt.suptitle("ducation level percentages of Asian-Pac-Islander race group in high-level income group")

ax = sns.barplot( x = occupation_class_2.index, y = occupation_class_2.values)

plt.xticks(rotation = 90)

for container in ax.containers:
    ax.bar_label(container);

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/G5KY8nf/93.png)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           31735 non-null  float64
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   gender                  32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
#  14  salary                  32537 non-null  object
#  15  education_summary       32537 non-null  object
#  16  marital_status_summary  32537 non-null  object
#  17  native_country_summary  32537 non-null  object
# dtypes: float64(1), int64(5), object(12)
# memory usage: 5.7+ MB

# %%
# Drop the columns of "education", "education_num", "relationship", "marital_status", "native_country" permanently

# Your Code is Here

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Check the missing values for all features basically**

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# **1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.**
#
# **2. Decide if drop these "Unknown" string values or not**

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# Unknown         1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
# Replace "Unknown" values with NaN using numpy library

# Your Code is Here

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# gender                       0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
# Drop missing values in df permanently

# Your Code is Here

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# gender                    0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   gender                  30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### Boxplot and Histplot for all numeric features
#
# **Plot boxplots for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/DKMSBDk/94.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/JKtcs9S/95.png)

# %% [markdown]
# **Plot both boxplots and histograms for each numeric features at the same figure as subplots**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/fMpP3yR/96.png)

# %% [markdown]
# **Check the statistical values for all numeric features**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/t3MJHDr/97.png)

# %% [markdown]
# **1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.**
#
# **2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.**

# %% [markdown]
# ### age

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/SnzH5Nz/98.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (28.0, 47.0, 19.0)

# %%
# Find lower and upper limit using IQR

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (-0.5, 75.5)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Define the observations whose age is greater than upper limit and sort these observations by age in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/x2wDgzQ/99.png)

# %% [markdown]
# ### hours_per_week

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/xq53X6w/100.png)

# %%
# Find IQR defining quantile 0.25 for low level and 0.75 for high level 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (40.0, 45.0, 5.0)

# %%
# Find the lower and upper limit using IQR

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (32.5, 52.5)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
# Define the observations where  hours per week are greater than upper limit and 
# sort these observations by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/zGCnbjz/101.png)

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/swYNtdM/102.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/S7RWpxD/103.png)

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %%
# Create a condition according to your domain knowledge on age stated above and 
# sort the observations meeting this condition by age in ascending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/pJC50ZV/104.png)

# %%
# Find the shape of the dataframe created by the condition defined above for age 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (76, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for age

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([  222, 18832, 10545, 11512, 11996, 12975, 14159, 15892, 18277,
#             18413, 18725, 19212,  8973, 19489, 19747, 20610, 22220, 24043,
#             28463, 31030, 32277, 32367, 10210, 15356,  5370,  4070,  1040,
#              6232,  1935,  2303,  5272,  6624,  2891,  5406,  8806,  1168,
#             22895, 21835, 24027, 20463,  8381, 32459, 26731, 27795,  9471,
#              6214, 14711, 11238,  7720, 15662,  7481, 24395, 23459, 19172,
#             16302, 14756,  8431, 20421, 22481, 31855, 13696, 24280,  4834,
#             29594, 28948, 12830,   918, 13295, 24560,  3537, 13928, 19045,
#              6748,  2906, 21501, 19495],
#            dtype='int64')

# %%
# Drop these indices defined above for age

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on hours per week stated above and 
# sort the observations meeting this condition by hours per week in descending order

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/rMp7C58/105.png)

# %%
# Find the shape of the dataframe created by the condition defined above for hours per week 

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (621, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
# Drop these indices defined above for hours per week

# Your Code is Here

# %%
# Create a condition according to your domain knowledge on both age and hours per week stated above 

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Ch8XSdW/106.png)

# %%
# Find the shape of the dataframe created by the condition defined above for both age and hours per week


# Your Code is Here

# %% [raw]
# Desired Output:
#
# (23, 13)

# %%
# Assign the indices of the rows defined in accordance with condition above for both age and hours per week

# Your Code is Here

# %% [raw]
# Desired Output:
#
# Int64Index([ 1541,  2154,  2184,  2665,  3101,  5417,  6826,  8066,  9646,
#             12624, 16634, 18367, 19584, 20125, 23399, 23585, 24903, 25910,
#             26625, 27721, 28294, 31342, 32192],
#            dtype='int64')

# %%
# Drop these indices defined above for both age and hours per week

# Your Code is Here

# %%
# What is new shape of dataframe now

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# Reset the indices and take the head of DataFrame now

# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5MXPD2b/107.png)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# **Convert target feature (salary) to numeric (0 and 1) by using map function**

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 29969    0
# 29970    1
# 29971    0
# 29972    0
# 29973    1
# Name: salary, Length: 29974, dtype: int64

# %%
# Your Code is Here

# %% [raw]
# Desired Output:
#
# 0    22524
# 1     7450
# Name: salary, dtype: int64

# %% [markdown]
# **Convert all features to numeric by using get_dummies function**

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0F1SHRt/108.png)

# %%
# What's the shape of dataframe

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 13)

# %%
# What's the shape of dataframe created by dummy operation

# Your Code is Here

# %% [raw]
# Desired Output:
#
# (29974, 34)

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/Dgb8RYZ/109.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/5XH3X4q/110.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/19RytkS/111.png)

# %%
# Your Code is Here

# %% [markdown]
# ![image.png](https://i.ibb.co/80GcYKr/112.png)

# %%
# Your Code is Here

# %% [markdown]
# Desired Output:
#
# ![image.png](https://i.ibb.co/0MCPc4d/113.png)

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
